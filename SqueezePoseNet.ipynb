# %%
from google.colab import drive
drive.mount("/content/gdrive", force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import sys
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet')
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet/SqueezePoseNet')
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet/ShopFacade')
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet/KingsCollege')
sys.path.append('/content/gdrive/My Drive/GreatCourt')
sys.path.append('/content/gdrive/My Drive/OldHospital')
sys.path.append('/content/gdrive/My Drive/Church')
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet/KingsCollege')
# sys.path.append('/content/gdrive/My Drive/Hourglass/KingsCollege')
sys.path.append('/content/gdrive/My Drive/SqueezePoseNet/ETHMav/Images')
sys.path.append('/content/summary_Resnet')
sys.path.append('/content/models_Resnet')
sys.path.append('best_net.pth')
print (sys.path)
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython', '/content/gdrive/My Drive/SqueezePoseNet', '/content/gdrive/My Drive/SqueezePoseNet/SqueezePoseNet', '/content/gdrive/My Drive/SqueezePoseNet/ShopFacade', '/content/gdrive/My Drive/SqueezePoseNet/KingsCollege', '/content/gdrive/My Drive/GreatCourt', '/content/gdrive/My Drive/OldHospital', '/content/gdrive/My Drive/Church', '/content/gdrive/My Drive/SqueezePoseNet/KingsCollege', '/content/gdrive/My Drive/SqueezePoseNet/ETHMav/Images', '/content/summary_Resnet', '/content/models_Resnet', 'best_net.pth', '/content/gdrive/My Drive/SqueezePoseNet', '/content/gdrive/My Drive/SqueezePoseNet/SqueezePoseNet', '/content/gdrive/My Drive/SqueezePoseNet/ShopFacade', '/content/gdrive/My Drive/SqueezePoseNet/KingsCollege', '/content/gdrive/My Driv
# ...

# %%
import torch
# import data_loader
# import model
# import run_sequential_eval
# #import sample_tester
# import solver
# import test
# import train
# import pose_utils

USE_GPU = True


if USE_GPU and torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

print('using device:', device)
# Out:
# using device: cuda

# %%
#!python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/SqueezePoseNet/KingsCollege --metadata_path gdrive/My\ Drive/SqueezePoseNet/KingsCollege/dataset_train.txt
#!python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/SqueezePoseNet/ShopFacade --metadata_path gdrive/My\ Drive/SqueezePoseNet/ShopFacade/dataset_train.txt
#!python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/SqueezePoseNet/ETHMav --metadata_path gdrive/My\ Drive/SqueezePoseNet/ETHMav/dataset_train2.txt
# !python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/Church --metadata_path gdrive/My\ Drive/Church/dataset_train.txt
# Out:
# Streaming output truncated to the last 5000 lines.
# 44th train Loss: total loss 3.333 / pos loss 2.563 / ori loss 0.002
# 45th train Loss: total loss 4.152 / pos loss 3.514 / ori loss 0.001
# 46th train Loss: total loss 34.360 / pos loss 2.799 / ori loss 0.063
# 47th train Loss: total loss 2.598 / pos loss 2.128 / ori loss 0.001
# 48th train Loss: total loss 2.298 / pos loss 1.908 / ori loss 0.001
# 49th train Loss: total loss 5.565 / pos loss 4.850 / ori loss 0.001
# 50th train Loss: total loss 4.990 / pos loss 3.955 / ori loss 0.002
# 51th train Loss: total loss 4.496 / pos loss 3.722 / ori loss 0.002
# 52th train Loss: total loss 6.439 / pos loss 5.896 / ori loss 0.001
# 53th train Loss: total loss 3.277 / pos loss 2.803 / ori loss 0.001
# 54th train Loss: total loss 2.903 / pos loss 2.201 / ori loss 0.001
# 55th train Loss: total loss 5.142 / pos loss 4.181 / ori loss 0.002
# 56th train Loss: total loss 5.068 / pos loss 4.312 / ori loss 0.002
# ...

# %%
# !python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/GreatCourt --metadata_path gdrive/My\ Drive/GreatCourt/dataset_train.txt
#!python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/train.py --image_path gdrive/My\ Drive/Church --metadata_path gdrive/My\ Drive/Church/dataset_train.txt

# %%
#test
# !python3 gdrive/My\ Drive/SqueezePoseNet/SqueezePoseNet/test.py --metadata_path gdrive/My\ Drive/Church/dataset_test.txt \
 --pretrained_model best \
 --image_path gdrive/My\ Drive/Church \
 --bayesian True
# Out:
# 2020-06-04 19:04:09.992139: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Using TensorFlow backend.
# 530
# seq13/frame00155.png 27.616028 -0.242176 54.205308 0.362095 -0.008852 0.924934 -0.115366
#
# Number of Train 0
# Number of Test 530
# ********************
# Resnet
# ********************
# Load pretrained network:  models_Resnet/best_net.pth
# Load pretrained model:  models_Resnet/best_net.pth
# 0
# pose_var 9.203952955413724
# ori_var 5.061961652784454
# 49th Error: pos error 3.522 / ori error 0.972
# {}th std: pos / ori 9.203952955413724 5.061961652784454
# 1
# pose_var 14.256009297420006
# ori_var 1.4503008195846707
# 49th Error: pos error 0.124 / ori error 0.250
# {}th std: pos / ori 14.256009297420006 1.4503008195846707
# 2
# pose_var 11.847040982443705
# ori_var 2.772140327762826
# 49th Error: pos error 0.842 / ori error 0.470
# {}th std: pos / ori 11.847040982443705 2.772140327762826
# 3
# ...
